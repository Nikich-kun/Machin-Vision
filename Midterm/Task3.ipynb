# %%
from scipy import ndimage
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
from skimage import color
from skimage import io
from skimage import util

import matplotlib.image as pltimg
zelda =  io.imread('3ee19975f37a87a82b1c7c82c2fbf51e--game-poster-best-games.jpg')
img_s_p = util.random_noise(zelda, mode='s&p', seed=None, clip=True)

fig = plt.figure(figsize=(35,35))
plt.subplot(711)
plt.title('Original')
plt.imshow(zelda)

flt = ndimage.median_filter(zelda, 3)

plt.subplot(712)
plt.title('S&P')
plt.imshow(img_s_p)
plt.subplot(713)
plt.title('Median Filter')
plt.imshow(flt)




plt.show()
